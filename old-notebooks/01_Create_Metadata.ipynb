# %%
import os
import pydicom
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # Labels and meta information loading

# %%
images_info_path = "../data/raw/Train_Information/ProstateX-Images-Train.csv"
findings_info_path = "../data/raw/Train_Information/ProstateX-Findings-Train.csv"
mhd_images_info_path= "../data/raw/Train_Information/ProstateX-Images-KTrans-Train.csv"

# %%
images_info = pd.read_csv(images_info_path)
images_info.columns
# Out:
# Index(['ProxID', 'Name', 'fid', 'pos', 'WorldMatrix', 'ijk', 'TopLevel',
#        'SpacingBetweenSlices', 'VoxelSpacing', 'Dim', 'DCMSerDescr',
#        'DCMSerNum'],
#       dtype='object')

# %%
findings_info = pd.read_csv(findings_info_path)
findings_info.columns
# Out:
# Index(['ProxID', 'fid', 'pos', 'zone', 'ClinSig'], dtype='object')

# %% [markdown]
# ## Import MHD Information

# %%
mhd_image_info = pd.read_csv(mhd_images_info_path)
mhd_image_info["DCMSerDescr"] = "KTrans"
mhd_image_info.head()
# Out:
#            ProxID  fid                                                pos  \
# 0  ProstateX-0000    1                            25.7457 31.8707 -38.511
# 1  ProstateX-0001    1  -40.5367071921656 29.320722668457 -16.70766907...
# 2  ProstateX-0002    1                          -27.0102 41.5467 -26.0469
# 3  ProstateX-0002    2                            -2.058 38.6752 -34.6104
# 4  ProstateX-0003    1                           22.1495 31.2717 -2.45933
#
#                                          WorldMatrix       ijk DCMSerDescr
# 0  1.5,3.00503e-010,0.00377059,-58.4317,-0.000597...   56 75 7      KTrans
# 1  1.5,3.07655e-010,-4.64581e-017,-116.977,-3.057...   51 61 6      KTrans
# 2  1.5,3.07655e-010,7.98512e-017,-104.284,-2.9890...  52 73 11      KTrans
# 3  1.5,3.07655e-010,7.98512e-017,-104.284,-2.9890...   68 72 8      KTrans
# 4  1.5,3.07655e-010,3.75383e-017,-98.5005,-2.5684...  80 69 10      KTrans

# %%
mri_metadata = pd.merge(images_info, findings_info, left_on=["ProxID", "fid", "pos"], right_on=["ProxID", "fid", "pos"])

# %%
mhd_metadata = pd.merge(mhd_image_info, findings_info, left_on=["ProxID", "fid", "pos"], right_on=["ProxID", "fid", "pos"])
mhd_metadata.head()
# Out:
#            ProxID  fid                                                pos  \
# 0  ProstateX-0000    1                            25.7457 31.8707 -38.511
# 1  ProstateX-0001    1  -40.5367071921656 29.320722668457 -16.70766907...
# 2  ProstateX-0002    1                          -27.0102 41.5467 -26.0469
# 3  ProstateX-0002    2                            -2.058 38.6752 -34.6104
# 4  ProstateX-0003    1                           22.1495 31.2717 -2.45933
#
#                                          WorldMatrix       ijk DCMSerDescr  \
# 0  1.5,3.00503e-010,0.00377059,-58.4317,-0.000597...   56 75 7      KTrans
# 1  1.5,3.07655e-010,-4.64581e-017,-116.977,-3.057...   51 61 6      KTrans
# 2  1.5,3.07655e-010,7.98512e-017,-104.284,-2.9890...  52 73 11      KTrans
# 3  1.5,3.07655e-010,7.98512e-017,-104.284,-2.9890...   68 72 8      KTrans
# 4  1.5,3.07655e-010,3.75383e-017,-98.5005,-2.5684...  80 69 10      KTrans
#
#   zone  ClinSig
# 0   PZ     True
# 1   AS    False
# 2   PZ     True
# 3   PZ    False
# 4   TZ    False

# %%
metadata_labels = pd.concat([mri_metadata, mhd_metadata], sort= False)
metadata_labels[['i', 'j', 'k']] = metadata_labels["ijk"].str.split(" ", expand=True)
metadata_labels.head()
# Out:
#            ProxID                             Name  fid  \
# 0  ProstateX-0000       ep2d_diff_tra_DYNDIST_ADC0    1
# 1  ProstateX-0000           ep2d_diff_tra_DYNDIST0    1
# 2  ProstateX-0000           ep2d_diff_tra_DYNDIST1    1
# 3  ProstateX-0000           ep2d_diff_tra_DYNDIST2    1
# 4  ProstateX-0000  ep2d_diff_tra_DYNDISTCALC_BVAL0    1
#
#                        pos                                        WorldMatrix  \
# 0  25.7457 31.8707 -38.511  2,4.0067e-010,0.00377059,-46.6873,-0.000797221...
# 1  25.7457 31.8707 -38.511  2,4.0067e-010,0.00377059,-46.6873,-0.000797221...
# 2  25.7457 31.8707 -38.511  2,4.0067e-010,0.00377059,-46.6873,-0.000797221...
# 3  25.7457 31.8707 -38.511  2,4.0067e-010,0.00377059,-46.6873,-0.000797221...
# 4  25.7457 31.8707 -38.511  2,4.0067e-010,0.00377059,-46.6873,-0.000797221...
#
#        ijk  TopLevel  SpacingBetweenSlices VoxelSpacing          Dim  \
# 0  36 72 9       1.0                   3.0        2,2,3  84x128x19x1
# 1  36 72 9       1.0                   3.0        2,2,3  84x128x19x1
# 2  36 72 9       1.0                   3.0        2,2,3  84x128x19x1
# 3  36 72 9       1.0                   3.0        2,2,3  84x128x19x1
# 4  36 72 9       1.0                   3.0        2,2,3  84x128x19x1
#
#                       DCMSerDescr  DCMSerNum zone  ClinSig   i   j  k
# 0       ep2d_diff_tra_DYNDIST_ADC        7.0   PZ     True  36  72  9
# 1           ep2d_diff_tra_DYNDIST        6.0   PZ     True  36  72  9
# 2           ep2d_diff_tra_DYNDIST        6.0   PZ     True  36  72  9
# 3           ep2d_diff_tra_DYNDIST        6.0   PZ     True  36  72  9
# 4  ep2d_diff_tra_DYNDISTCALC_BVAL        8.0   PZ     True  36  72  9

# %%
metadata_labels
# Out:
#              ProxID                                 Name  fid  \
# 0    ProstateX-0000           ep2d_diff_tra_DYNDIST_ADC0    1
# 1    ProstateX-0000               ep2d_diff_tra_DYNDIST0    1
# 2    ProstateX-0000               ep2d_diff_tra_DYNDIST1    1
# 3    ProstateX-0000               ep2d_diff_tra_DYNDIST2    1
# 4    ProstateX-0000      ep2d_diff_tra_DYNDISTCALC_BVAL0    1
# 5    ProstateX-0000                          t2_tse_cor0    1
# 6    ProstateX-0000                          t2_tse_sag0    1
# 7    ProstateX-0000                          t2_tse_tra0    1
# 8    ProstateX-0000        tfl_3d_PD_ref_tra_1_5x1_5_t30    1
# 9    ProstateX-0001       ep2d_diff_tra_DYNDIST_MIX_ADC0    1
# 10   ProstateX-0001           ep2d_diff_tra_DYNDIST_MIX0    1
# 11   ProstateX-0001           ep2d_diff_tra_DYNDIST_MIX1    1
# 12   ProstateX-0001           ep2d_diff_tra_DYNDIST_MIX2    1
# 13   ProstateX-0001  ep2d_diff_tra_DYNDIST_MIXCALC_BVAL0    1
# 14   ProstateX-0001                          t2_loc_sag0    1
# 15   ProstateX-0001                        t2_localizer0    1
# 16   ProstateX-0001                        t2_localizer0    1
# 17   ProstateX-0001                          t2_tse_cor0    1
# 18   ProstateX-0001                          t2_tse_sag0    1
# 19   ProstateX-0001                          t2_tse_tra0    1
# 20   ProstateX-0001                          t2_tse_tra0    1
# 21   ProstateX-0001        tfl_3d_PD_ref_tra_1_5x1_5_t30    1
# 22   ProstateX-0002           ep2d_diff_tra_DYNDIST_ADC0    2
# 23   ProstateX-0002               ep2d_diff_tra_DYNDIST0    2
# 24   ProstateX-0002               ep2d_diff_tra_DYNDIST1    2
# 25   ProstateX-0002               ep2d_diff_tra_DYNDIST2    2
# 26   ProstateX-0002      ep2d_diff_tra_DYNDISTCALC_BVAL0    2
# 27   ProstateX-0002                          t2_loc_sag0    2
# 28   ProstateX-0002                        t2_localizer0    2
# 29   ProstateX-0002                          t2_tse_cor0    2
# ..              ...                                  ...  ...
# 305  ProstateX-0187                                  NaN    4
# 306  ProstateX-0188                                  NaN    1
# 307  ProstateX-0189                                  NaN    1
# 308  ProstateX-0189                                  NaN    2
# 309  ProstateX-0189                                  NaN    3
# 310  ProstateX-0190                                  NaN    1
# 311  ProstateX-0190                                  NaN    2
# 312  ProstateX-0191                                  NaN    1
# 313  ProstateX-0192                                  NaN    1
# 314  ProstateX-0192                                  NaN    2
# 315  ProstateX-0193                                  NaN    1
# 316  ProstateX-0193                                  NaN    2
# 317  ProstateX-0193                                  NaN    3
# 318  ProstateX-0193                                  NaN    4
# 319  ProstateX-0194                                  NaN    1
# 320  ProstateX-0195                                  NaN    1
# 321  ProstateX-0196                                  NaN    1
# 322  ProstateX-0196                                  NaN    2
# 323  ProstateX-0196                                  NaN    3
# 324  ProstateX-0197                                  NaN    1
# 325  ProstateX-0198                                  NaN    1
# 326  ProstateX-0199                                  NaN    1
# 327  ProstateX-0199                                  NaN    2
# 328  ProstateX-0200                                  NaN    1
# 329  ProstateX-0200                                  NaN    2
# 330  ProstateX-0201                                  NaN    1
# 331  ProstateX-0202                                  NaN    1
# 332  ProstateX-0202                                  NaN    2
# 333  ProstateX-0203                                  NaN    1
# 334  ProstateX-0203                                  NaN    2
#
#                                                    pos  \
# 0                              25.7457 31.8707 -38.511
# 1                              25.7457 31.8707 -38.511
# 2                              25.7457 31.8707 -38.511
# 3                              25.7457 31.8707 -38.511
# 4                              25.7457 31.8707 -38.511
# 5                              25.7457 31.8707 -38.511
# 6                              25.7457 31.8707 -38.511
# 7                              25.7457 31.8707 -38.511
# 8                              25.7457 31.8707 -38.511
# 15                55.4762  1.5625,1.5625,55.4762  256x256x13x1
# 16                55.4762  1.5625,1.5625,55.4762  256x256x13x1
# 17                 3.0000              0.6,0.6,3  320x320x15x1
# 18                 3.6000      0.5625,0.5625,3.6  320x320x19x1
# 19                 3.0000              0.5,0.5,3  384x384x19x1
# 20                 3.0000              0.5,0.5,3  384x384x19x1
# 21                 3.0000              1.5,1.5,3  128x128x16x1
# 22                 3.0000                  2,2,3   84x128x19x1
# 23                 3.0000                  2,2,3   84x128x19x1
# 24                 3.0000                  2,2,3   84x128x19x1
# 25                 3.0000                  2,2,3   84x128x19x1
# 26                 3.0000                  2,2,3   84x128x19x1
# 27                10.5000     1.5625,1.5625,10.5   256x256x3x1
# 28                55.4762  1.5625,1.5625,55.4762  256x256x13x1
# 29                 3.0000              0.6,0.6,3  320x320x15x1
# ..                    ...                    ...           ...
# 305                   NaN                    NaN           NaN
# 306                   NaN                    NaN           NaN
# 307                   NaN                    NaN           NaN
# 308                   NaN                    NaN           NaN
# 309                   NaN                    NaN           NaN
# 310                   NaN                    NaN           NaN
# 311                   NaN                    NaN           NaN
# 312                   NaN                    NaN           NaN
# 313                   NaN                    NaN           NaN
# 314                   NaN                    NaN           NaN
# 315                   NaN                    NaN           NaN
# 316                   NaN                    NaN           NaN
# 317                   NaN                    NaN           NaN
# 318                   NaN                    NaN           NaN
# 319                   NaN                    NaN           NaN
# 320                   NaN                    NaN           NaN
# 321                   NaN                    NaN           NaN
# 322                   NaN                    NaN           NaN
# 323                   NaN                    NaN           NaN
# 324                   NaN                    NaN           NaN
# 325                   NaN                    NaN           NaN
# 326                   NaN                    NaN           NaN
# 327                   NaN                    NaN           NaN
# 328                   NaN                    NaN           NaN
# 329                   NaN                    NaN           NaN
# 330                   NaN                    NaN           NaN
# 331                   NaN                    NaN           NaN
# 332                   NaN                    NaN           NaN
# 333                   NaN                    NaN           NaN
# 334                   NaN                    NaN           NaN
#
#                             DCMSerDescr  DCMSerNum zone  ClinSig    i    j   k
# 0             ep2d_diff_tra_DYNDIST_ADC        7.0   PZ     True   36   72   9
# 1                 ep2d_diff_tra_DYNDIST        6.0   PZ     True   36   72   9
# 2                 ep2d_diff_tra_DYNDIST        6.0   PZ     True   36   72   9
# 3                 ep2d_diff_tra_DYNDIST        6.0   PZ     True   36   72   9
# 4        ep2d_diff_tra_DYNDISTCALC_BVAL        8.0   PZ     True   36   72   9
# 5                            t2_tse_cor        5.0   PZ     True  139  166  12
# 6                            t2_tse_sag        3.0   PZ     True  176  169  13
# 7                            t2_tse_tra        4.0   PZ     True  167  224   9
# 8          tfl_3d PD ref_tra_1.5x1.5_t3        9.0   PZ     True   56   75   7
# 9         ep2d_diff_tra_DYNDIST_MIX_ADC        8.0   AS    False   34   63  10
# 10            ep2d_diff_tra_DYNDIST_MIX        7.0   AS    False   34   63  10
# 11            ep2d_diff_tra_DYNDIST_MIX        7.0   AS    False   34   63  10
# 12            ep2d_diff_tra_DYNDIST_MIX        7.0   AS    False   34   63  10
# 13   ep2d_diff_tra_DYNDIST_MIXCALC_BVAL        9.0   AS    False   34   63  10
# 14                           t2_loc sag        3.0   AS    False  126  145   3
# 15                         t2_localizer        1.0   AS    False  147  139   1
# 16                         t2_localizer        2.0   AS    False  147  139   1
# 17                           t2_tse_cor        5.0   AS    False  131  177   6
# 18                           t2_tse_sag        4.0   AS    False  154  173  15
# 19                           t2_tse_tra        6.0   AS    False  157  186  10
# 20                           t2_tse_tra       10.0   AS    False  157  186  10
# 21         tfl_3d PD ref_tra_1.5x1.5_t3       11.0   AS    False   51   61   6
# 22            ep2d_diff_tra_DYNDIST_ADC        7.0   PZ    False   45   70   9
# 23                ep2d_diff_tra_DYNDIST        6.0   PZ    False   45   70   9
# 24                ep2d_diff_tra_DYNDIST        6.0   PZ    False   45   70   9
# 25                ep2d_diff_tra_DYNDIST        6.0   PZ    False   45   70   9
# 26       ep2d_diff_tra_DYNDISTCALC_BVAL        8.0   PZ    False   45   70   9
# 27                           t2_loc sag        2.0   PZ    False  134  137   1
# 28                         t2_localizer        1.0   PZ    False  153  151   0
# 29                           t2_tse_cor        5.0   PZ    False  170  186  12
# ..                                  ...        ...  ...      ...  ...  ...  ..
# 305                              KTrans        NaN   AS    False   76   58  12
# 306                              KTrans        NaN   PZ    False   50   54   8
# 307                              KTrans        NaN   PZ    False   68   71   4
# 308                              KTrans        NaN   PZ    False   60   70   9
# 309                              KTrans        NaN   PZ    False   62   65   1
# 310                              KTrans        NaN   PZ     True   65   64   3
# 311                              KTrans        NaN   PZ    False   72   63   7
# 312                              KTrans        NaN   AS    False   92   83   9
# 313                              KTrans        NaN   PZ     True   74   73   5
# 314                              KTrans        NaN   PZ    False   56   73  10
# 315                              KTrans        NaN   AS    False   62   49   7
# 316                              KTrans        NaN   PZ    False   70   70   8
# 317                              KTrans        NaN   PZ    False   55   67  12
# 318                              KTrans        NaN   PZ     True   62   71   6
# 319                              KTrans        NaN   TZ     True   49   59   4
# 320                              KTrans        NaN   PZ     True   57   70   4
# 321                              KTrans        NaN   PZ     True   58   66   5
# 322                              KTrans        NaN   PZ     True   73   63   4
# 323                              KTrans        NaN   PZ     True   55   57   4
# 324                              KTrans        NaN   TZ     True   57   66   6
# 325                              KTrans        NaN   AS     True   62   51   5
# 326                              KTrans        NaN   AS     True   66   58   9
# 327                              KTrans        NaN   AS     True   57   62   6
# 328                              KTrans        NaN   AS     True   75   68   6
# 329                              KTrans        NaN   PZ    False   52   64   7
# 330                              KTrans        NaN   AS     True   74   65  10
# 331                              KTrans        NaN   AS     True   67   61   6
# 332                              KTrans        NaN   PZ    False   60   74   5
# 333                              KTrans        NaN   AS     True   59   56   7
# 334                              KTrans        NaN   PZ     True   71   65   5
#
# [4204 rows x 17 columns]

# %%
metadata_labels.to_csv("../data/interim/train_information.csv")
